# %%
import librosa

file_path = "/home/zzh/Projects/Audio/assets/noise1.wav"
samples, sampling_rate = librosa.load(file_path)
len(samples), sampling_rate
# Out:
# /home/zzh/.local/lib/python3.6/site-packages/numba/core/errors.py:154: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)
# (231392, 22050)

# %%
duration_of_sound = len(samples) / sampling_rate
print(duration_of_sound, " seconds")
# Out:
# 10.493968253968253  seconds

# %%
from IPython.display import Audio
Audio(file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from librosa import display
import matlibplot.pyplot as plt
plt.figure()
librosa.display.waveplot(y = samples, sr = sampling_rate)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-ddb0f86a2f35> in <module>
# ----> 1 from librosa import display
#       2 import matlibplot.pyplot as plt
#       3 plt.figure()
#       4 librosa.display.waveplot(y = samples, sr = sampling_rate)
#       5 plt.show()
#
# ~/.local/lib/python3.6/site-packages/librosa/display.py in <module>
#      46
#      47 import numpy as np
# ---> 48 from matplotlib.cm import get_cmap
#      49 from matplotlib.axes import Axes
#      50 from matplotlib.ticker import Formatter, ScalarFormatter
#
# ModuleNotFoundError: No module named 'matplotlib'
