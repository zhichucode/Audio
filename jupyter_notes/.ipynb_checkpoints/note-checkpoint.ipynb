# %%
import librosa
file_path = "/home/zzh/Projects/Audio/assets/noise1.wav"
samples, sampling_rate = librosa.load(file_path)
duration_of_sound = len(samples) / sampling_rate
len(samples), sampling_rate, duration_of_sound
# Out:
# (231392, 22050, 10.493968253968253)

# %%
## from IPython.display import Audio
Audio(file_path)

from librosa import display
import matplotlib.pyplot as plt
plt.figure()
librosa.display.waveplot(y = samples, sr = sampling_rate)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

SAMPLE_RATE = 44100
DURATION = 5

def generate_sine_wave(freq, sample_rate, duration):
    x = np.linspace(0, duration, sample_rate * duration, endpoint=False)
    frequencies = x * freq
    # 2pi because np.sin takes radians
    y = np.sin((2 * np.pi) * frequencies)
    return x, y

# %%
_, nice_tone = generate_sine_wave(400, SAMPLE_RATE, DURATION)
_, noise_tone = generate_sine_wave(4000,SAMPLE_RATE, DURATION)
noise_tone = noise_tone * 0.3
mixed_tone = nice_tone + noise_tone
normalized_tone = np.int16((mixed_tone / mixed_tone.max()) * 32767)
plt.plot(normalized_tone[:1000])
plt.show()

# %%
from scipy.io.wavfile import write
write("assets/mysinewave.wav", SAMPLE_RATE, normalized_tone)

# %%
from scipy.fft import fft, fftfreq

# Number of samples in normalized_tone
N = SAMPLE_RATE * DURATION

yf = fft(normalized_tone)
xf = fftfreq(N, 1 / SAMPLE_RATE)

plt.plot(xf, np.abs(yf))
plt.show()

# %%
from scipy.fft import rfft, rfftfreq

# Note the extra 'r' at the front
yf = rfft(normalized_tone)
xf = rfftfreq(N, 1 / SAMPLE_RATE)

plt.plot(xf, np.abs(yf))
plt.show()
