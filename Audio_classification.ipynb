# %% [markdown]
# <a href="https://colab.research.google.com/github/zhichucode/Audio/blob/master/Audio_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font size = '6'><center>**Audio Classification**</center></font>
#
# Here I am extracting a sample of audios from the VoxCeleb dataset for gender classification. In this notebook, I am using spectrograms and a 2D CNN model for audio classification.
#
# VoxCeleb dataset - https://www.robots.ox.ac.uk/~vgg/data/voxceleb/

# %%
#import libraries
from urllib.request import urlopen
from zipfile import ZipFile

from IPython.display import HTML
from base64 import b64encode
import matplotlib.pyplot as plt

import os
import glob
import numpy as np
import pandas as pd
import cv2     # for capturing videos
import math
import random

import moviepy.editor as mp
from IPython.display import clear_output

import IPython
import librosa

from scipy.io import wavfile
import os
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %% [markdown]
# # **Download and unzip the data**

# %%
#get url
# !wget "https://thor.robots.ox.ac.uk/~vgg/data/voxceleb/vox1a/vox2_test_mp4.zip"
# Out:
# --2022-03-08 14:27:46--  https://thor.robots.ox.ac.uk/~vgg/data/voxceleb/vox1a/vox2_test_mp4.zip
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8906971319 (8.3G) [application/zip]
# Saving to: ‘vox2_test_mp4.zip’
#
# vox2_test_mp4.zip   100%[===================>]   8.29G   130MB/s    in 1m 48s
#
# 2022-03-08 14:29:35 (78.5 MB/s) - ‘vox2_test_mp4.zip’ saved [8906971319/8906971319]

# %%
# !unzip vox2_test_mp4.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: mp4/id05999/tZe9RtGYPu8/00255.mp4
#   inflating: mp4/id05999/tZe9RtGYPu8/00257.mp4
#   inflating: mp4/id05999/tZe9RtGYPu8/00264.mp4
#   inflating: mp4/id05999/tZe9RtGYPu8/00266.mp4
#   inflating: mp4/id05999/tZe9RtGYPu8/00268.mp4
#   inflating: mp4/id05999/tZe9RtGYPu8/00260.mp4
#   inflating: mp4/id05999/tZe9RtGYPu8/00259.mp4
#   inflating: mp4/id05999/tZe9RtGYPu8/00270.mp4
#   inflating: mp4/id05999/tZe9RtGYPu8/00269.mp4
#   inflating: mp4/id05999/tZe9RtGYPu8/00267.mp4
#   inflating: mp4/id05999/tZe9RtGYPu8/00256.mp4
#    creating: mp4/id05999/U8TaxVpPsSg/
#   inflating: mp4/id05999/U8TaxVpPsSg/00160.mp4
#   inflating: mp4/id05999/U8TaxVpPsSg/00162.mp4
#   inflating: mp4/id05999/U8TaxVpPsSg/00159.mp4
#   inflating: mp4/id05999/U8TaxVpPsSg/00161.mp4
#    creating: mp4/id05999/crh0LREMv-8/
#   inflating: mp4/id05999/crh0LREMv-8/00196.mp4
#   inflating: mp4/id05999/crh0LREMv-8/00194.mp4
# ...

# %% [markdown]
# #**Organizing the data**

# %% [markdown]
# In the cells below I am collecting all the video paths in a list. I will be then using these videos to extract the audios and their spectrograms to feed in to the neural network.

# %%
#get video paths
vid_paths = []

for path, directories, files in os.walk('/content/mp4/'):

  for file in files:

    vid_paths.append(str(path) + '/' + str(file))

# %%
#number of videos available
print('Number of videos available: ', len(vid_paths))

#shuffle video paths. I have used a random seed of 4 to shuffle.
random.seed(4)
random.shuffle(vid_paths)
# Out:
# Number of videos available:  36237

# %% [markdown]
# # **Upload the CSV file and clean**

# %% [markdown]
# The csv file with meta data is in my github repository. (https://github.com/kaneelgit/msi_voxceleb). You have to upload the csv file to colab before running the following cells.

# %%
#some functions to clean the csv file
#del spaces from the ids and gender
def del_spaces(string):
  
  string = string.replace(' ', '')

  return string

#upload csv file from github before running
#open csv file
df = pd.read_csv('/content/vox2_meta.csv')
df.head(5)

#clean the dataset

#apply the function to get rid of spaces
df['VoxCeleb2 ID'] = df['VoxCeleb2 ID'].apply(del_spaces)
df['VGGFace2 ID'] = df['VGGFace2 ID'].apply(del_spaces)
df['Gender'] = df['Gender'].apply(del_spaces)
df['Set'] = df['Set'].apply(del_spaces)


#get the test data
df2 = df[df['Set'] == 'test']
df2['Gender'] = df2['Gender'].astype('category')

df2.head(5)
# Out:
#     VoxCeleb2 ID VGGFace2 ID Gender   Set
# 3        id00017     n000017      m  test
# 36       id00061     n000061      m  test
# 53       id00081     n000081      m  test
# 89       id00154     n000154      m  test
# 271      id00419     n000419      f  test

# %% [markdown]
# # **Create a Labels List**

# %% [markdown]
# Here I am going through the ids of all the video files and picking the gender from the CSV file. Note that there are double the size of male videos compared to female. So I will be taking every other video file to balance the dataset.

# %%
#iterate through the vid_paths get the id of the person and get if the person is female or male. If the person is male its a 1 and female its a 0
labels = []

#get only half of the male videos.
count = 0
video_files = []

#iterate
for path in vid_paths:
  
  #get id number
  id_str =  path[13:20]

  #get if the subject is male or female from the csv
  gender = df2.loc[df2['VoxCeleb2 ID'] == str(id_str)]['Gender'].values[0]

  if gender == 'm':
    if count % 2 == 0:
      labels.append(1)
      video_files.append(path)
    count += 1
  
  else:
    labels.append(0)
    video_files.append(path)

# %% [markdown]
# # **Extracting the Mel Spectrogram**

# %% [markdown]
# Next I have created a function to extract the audio from the video file, trim it to 3 seconds (Since I used 3 second video clips for my video_cnn_model) and convert the audio array to a mel spectrogram. If you don't know what a mel spectorgram <a href = "https://medium.com/analytics-vidhya/understanding-the-mel-spectrogram-fca2afa2ce53#:~:text=A%20mel%20spectrogram%20is%20a,converted%20to%20the%20mel%20scale.&text=What's%20amazing%20is%20that%20after,a%20couple%20lines%20of%20code." target = "_blank"> here </a> is a good read.

# %%
#convert from audio to a mel diagram
def aud_to_mel(path):
  
  #get video from path
  video = mp.VideoFileClip(path)
  video = video.subclip(0, 3)

  #get the audio
  x = video.audio.to_soundarray()

  #get audio track to array
  #x = aud.to_soundarray()

  #sampling rate
  fs = 44100
  
  #channel 1
  ch1 = librosa.feature.melspectrogram(x[:, 0], sr = fs)
  mel_ch1 = librosa.amplitude_to_db(ch1, ref = np.min)

  #channel 2
  # ch2 = librosa.feature.melspectrogram(x[:, 1], sr = fs)
  # mel_ch2 = librosa.amplitude_to_db(ch2, ref = np.min)
  
  return mel_ch1.reshape(mel_ch1.shape[0], mel_ch1.shape[1], 1)

# %%
#lets plot a mel spectrogram
mel_spec_tmp = aud_to_mel(video_files[0])

#plot the spectrogram
plt.figure(figsize = (6, 6))
plt.title('Mel Spectrogram')
plt.imshow(mel_spec_tmp[:, :, 0])
plt.xlabel('Time')
plt.ylabel('Hz')
plt.show()

# %% [markdown]
# Here, I have created a data generator function. This generates audio data to the function given the batch size.
#
# *Note: I ran into memory issues when I ran used the data generator to feed data to the model. So I ended up stacking spectrograms to a numpy array to feed into the model*

# %%
#create a data generator
def audio_generator(paths, labels, batch_size = 16):

  while True:

    #get the number of batches
    number_of_batches = len(paths) // batch_size

    #set up video batches and label batches
    batches = [paths[i : i + batch_size] for i in range(0, len(paths), batch_size)]
    label_batches = [labels[i : i + batch_size] for i in range(0, len(paths), batch_size)]

    for b in range(number_of_batches):

      #create arrays to store the files
      x_batch = np.zeros([batch_size, 128, 259, 1])
      y_batch = np.zeros([batch_size, 1])

      #get the batch
      batch = batches[b]
      label_batch = label_batches[b]

      for i, p in enumerate(batch):
        
        audio_array = aud_to_mel(p)

        #store result
        x_batch[i, :] = audio_array
        y_batch[i, :] = label_batch[i]

      yield {'audio': x_batch}, {'class': y_batch}

# %% [markdown]
# # **Test/validation split**

# %% [markdown]
# Here I have manually seperated the train and validation set because I ran into memory issues in colab.

# %%
#split to train and validation set
train_idx = int(np.floor(len(labels) * 0.9))

#split the train and test data accordingly
train_paths = video_files[:train_idx]
train_labels = labels[:train_idx]

#split the test data
val_paths = video_files[train_idx:]
val_labels = labels[train_idx:]

# %%
#validation set
validation_set = np.zeros([150, 128, 259, 1])
validation_labels = np.zeros([150, 1])

#select 100 random indexes from the validation set
#rand_val_idx = np.random.choice(np.arange(len(val_paths)), 150)
rand_val_idx = np.arange(len(val_paths[:150]))

for i, idx in enumerate(rand_val_idx):

  #vid path
  path = val_paths[idx]
  label = val_labels[idx]

  validation_set[i, :] = aud_to_mel(path)
  validation_labels[i, :] = label

# %% [markdown]
# Here I am creating a training set by selecting 1600 videos to match the amount I used for the video cnn model. Since I will be comparing the three models (video, audio and video + audio) with each other I am trying to be consistent with training and testing.

# %%
#create a train set
training_set = np.zeros([1600, 128, 259, 1])
training_labels = np.zeros([1600, 1])

#select 1000 files from the train files
rand_train_idx = np.arange(len(train_paths[:1600]))

for i, idx in enumerate(rand_train_idx):

  #aud path
  path = train_paths[idx]
  label = train_labels[idx]

  training_set[i, :] = aud_to_mel(path)
  training_labels[i, :] = label

# %% [markdown]
# #**Create a 2D Convolutional Neural Network Model**

# %% [markdown]
# Below I have used the tensorflow functional API to create a convolutional neural network model

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import numpy as np
import scipy.misc
from tensorflow.keras.applications.resnet_v2 import ResNet50V2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet_v2 import preprocess_input, decode_predictions
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Add, Dense, Average, Activation, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D, Dropout, Concatenate
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import random_uniform, glorot_uniform, constant, identity
from tensorflow.python.framework.ops import EagerTensor
from tensorflow.python.keras.utils.vis_utils import plot_model

# %%
tf.__version__
# Out:
# '2.8.0'

# %%
#CNN MODEL
def cnn_model(x):
    
    inputs = x
    x = tf.keras.layers.Conv2D(16, kernel_size = (3, 3),activation = 'relu')(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPool2D(pool_size = (2, 2))(x)
    
    x = tf.keras.layers.Conv2D(32, kernel_size = (3, 3), activation = 'relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPool2D(pool_size = (2, 2))(x)
    
    x = tf.keras.layers.Conv2D(64, kernel_size = (3, 3), activation = 'relu')(x) 
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPool2D(pool_size = (2, 2))(x)
    
    # x = tf.keras.layers.Conv3D(64, kernel_size = (3, 3, 1), activation = 'relu')(x) 
    # x = tf.keras.layers.BatchNormalization()(x)
    # x = tf.keras.layers.MaxPool3D(pool_size = (2, 2, 1))(x)
   
    return x

#input
input_samp = np.zeros([16, 128, 259, 1])

#input
input = Input(input_samp[0, :].shape, name = 'audio')
out = cnn_model(input)
out = Flatten()(out)
out = Dropout(0.5)(out)
out = Dense(1024, activation = 'relu')(out)
out = Dropout(0.8)(out)
out = Dense(128, activation = 'relu')(out)
output = Dense(1, activation = 'sigmoid', name = 'class')(out)

#create the model
audio_cnn_model = Model(input, output)

#plot the model
try:
    plot_model(audio_cnn_model, show_shapes = True, show_layer_names = True, to_file = 'test_model.png')
except ImportError: pass

# %%
#compile the model
opt = tf.optimizers.Adam(0.001)

#learning rate scheduler
def lr_schedule(epoch, lr):
    
    if (epoch + 1) % 5 == 0:
        
        lr *= 0.2
    
    return max(lr, 3e-7)

opt = tf.keras.optimizers.SGD(
    learning_rate=0.01, momentum=0.0, nesterov=False, name='SGD')


#compile model
audio_cnn_model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = 'accuracy')

#callbacks
#create a callback to stop the model when loss get higher
cb = tf.keras.callbacks.EarlyStopping(monitor = 'loss', patience = 5, mode = 'auto')

cb_lr = tf.keras.callbacks.LearningRateScheduler(lr_schedule)

#fit model
# history = audio_cnn_model.fit(audio_generator(train_paths, train_labels, batch_size = 8), validation_data = (validation_set, validation_labels),\
#                     epochs = 10, steps_per_epoch = 100, callbacks = [cb])

history = audio_cnn_model.fit(x = training_set, y = training_labels, validation_data = (validation_set, validation_labels),\
                    batch_size = 8, epochs = 50, callbacks = [cb])
# Out:
# Epoch 1/50
# 200/200 [==============================] - 18s 29ms/step - loss: 7.3951 - accuracy: 0.6381 - val_loss: 0.5742 - val_accuracy: 0.6600
# Epoch 2/50
# 200/200 [==============================] - 5s 26ms/step - loss: 1.8711 - accuracy: 0.7675 - val_loss: 0.3859 - val_accuracy: 0.8400
# Epoch 3/50
# 200/200 [==============================] - 5s 25ms/step - loss: 1.2101 - accuracy: 0.8062 - val_loss: 0.3683 - val_accuracy: 0.8533
# Epoch 4/50
# 200/200 [==============================] - 5s 26ms/step - loss: 0.9217 - accuracy: 0.8194 - val_loss: 0.3623 - val_accuracy: 0.9067
# Epoch 5/50
# 200/200 [==============================] - 5s 26ms/step - loss: 0.5096 - accuracy: 0.8375 - val_loss: 0.4518 - val_accuracy: 0.8467
# Epoch 6/50
# 200/200 [==============================] - 5s 26ms/step - loss: 0.4646 - accuracy: 0.8544 - val_loss: 0.4655 - val_accuracy: 0.9267
# Epoch 7/50
# ...

# %% [markdown]
# # **Results Summary**

# %%
#accuracy vs loss 
plt.figure(figsize = (10, 6))
plt.plot(np.arange(len(history.history['loss'])), history.history['loss'], label = 'Training Loss', color = 'b')
plt.plot(np.arange(len(history.history['val_loss'])), history.history['val_loss'], label = 'Validation Loss', color = 'r')
plt.legend()
plt.title('Epoch vs Loss', fontsize = 18)
plt.xlabel('Epoch', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
plt.show()

plt.figure(figsize = (10, 6))
plt.plot(np.arange(len(history.history['loss'])), history.history['accuracy'], label = 'Training Accuracy', color = 'b')
plt.plot(np.arange(len(history.history['val_loss'])), history.history['val_accuracy'], label = 'Validation Accuracy', color = 'r')
plt.legend()
plt.title('Epoch vs Accuracy', fontsize = 18)
plt.xlabel('Epoch', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.show()

# %% [markdown]
# # **Save and download the model/weights**

# %%
audio_cnn_model.save_weights('/content/audition.h5')

from google.colab import files
files.download('audition.h5')
